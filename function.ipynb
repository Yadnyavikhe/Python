# %%
def sumdata(a,b):
    print(a+b)
    print(a*b)
sumdata(10,20)
sumdata(20,30)
# Out:
# 30
# 200
# 50
# 600

# %%
def sumdata(a,b):
    print(a+b)
    print(a*b)
    print(a-b)
    print(a/b)
sumdata(20,20)
# Out:
# 40
# 400
# 0
# 1.0

# %%
a="YADNYA"
print(a)
# Out:
# YADNYA

# %%
def sum(a,b=5):
    print(a+b)
sum(30)
# Out:
# 35

# %%
def sum(a,b,c=7):
    print(a+b+c)
sum(20,10)
# Out:
# 37

# %%
def sum(a,b):
    c=a+b
    return c
k=sum(2,5)    
k
# Out:
# 7

# %%
def mul(a,b):
    c=a*b
    return c
y=mul(4,5)
y
# Out:
# 20

# %%
def divide(a,b):
    c=a/b
    return c
b=divide(2,10)
b
# Out:
# 0.2

# %%
def sum(a,b):
    c=a+b
    return c
c=sum(2,3)

if c>4:
    print("yes")
else:
    print("no")
# Out:
# yes

# %%
class demo:
    def show(self,a,b):
        print(a+b)
obj=demo()
obj.show(2,3)
# Out:
# 5

# %%
class demo():
    def show(self,a=3,b=2,c=4):
        print(a*b,a+c,a*b+c*a*a)
obj=demo()
obj.show()
# Out:
# 6 7 42

# %%
class demo():
    def show(self,a,b,c=4):
        print(a*b,a+c,a*b+c*a*a)
obj=demo()
obj.show(2,3)
# Out:
# 6 6 22

# %%
class student:
    def _init_(self,name,percentage):
        print(name,percentage)
obj=student()
obj._init_("raj",90)
# Out:
# raj 90

# %%
class demo:
    def show(self,phone,price):
        print(phone,price)
obj=demo()
obj.show("Samsung",14000)
obj.show("iphone",15000)
obj.show("redmi",13000)
obj.show("poco",17000)
# Out:
# Samsung 14000
# iphone 15000
# redmi 13000
# poco 17000
