# %% [raw]
# print("Hello World")

# %%
a="Yadnya"
print(a)
# Out:
# Yadnya

# %%
b= "My name is yadnya \n my favourite color is pink"
print(b)
# Out:
# My name is yadnya
#  my favourite color is pink

# %%
a=10
print(a)
# Out:
# 10

# %%
a_10=10
print(a_10)
# Out:
# 10

# %%
a=5
print(a,a)
# Out:
# 5 5

# %%
a="Yadnya"
print(a)
print(id(a))
# Out:
# Yadnya
# 2389866035024

# %%
a="Hello"
b="Need Data"
print(a+b)
# Out:
# HelloNeed Data

# %%
a="Hello"
b="World"
print(a+b)
# Out:
# HelloWorld

# %%
a="Hello"
b=8.5
print(a,b)
# Out:
# Hello 8.5

# %%
a=10
b=5
print(a+b)
print(a-b)
print(a*b)
print(a/b)
# Out:
# 15
# 5
# 50
# 2.0

# %%
x=6
print(id(x))
# Out:
# 140705748763720

# %%
_a=70
_b=10
print(_a+_b)
# Out:
# 80

# %%
_name="Yadnya"
print(_name)
# Out:
# Yadnya
